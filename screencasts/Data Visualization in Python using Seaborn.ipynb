# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#get available dataset names from here 

mpg = sns.load_dataset('mpg')

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg["cylinders"].unique()
# Out:
# array([8, 4, 6, 3, 5])

# %%
sns.distplot(mpg['cylinders'], bins=6)

# %%
sns.distplot(mpg['cylinders'], bins=range(3,10,1))
plt.xticks(range(3,9,1))
# Out:
# ([<matplotlib.axis.XTick at 0x11a472b38>,
# ...
#  <a list of 6 Text xticklabel objects>)

# %%
sns.distplot(mpg["cylinders"], kde=False, bins=range(3,10,1))

# %%
sns.distplot(mpg["cylinders"], hist=False, bins=range(3,10,1))
plt.xticks(range(3,9,1))
# Out:
# ([<matplotlib.axis.XTick at 0x11a087f60>,
# ...
#  <a list of 6 Text xticklabel objects>)

# %%
sns.countplot(x = 'cylinders', data=mpg)

# %%
sns.countplot(x = 'cylinders', data=mpg, color='red')

# %%
mpg['origin'].unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %%
sns.countplot(x = 'cylinders', data=mpg, color='red', hue='origin')

# %%
sns.countplot(x = 'cylinders', data=mpg, color='blue', hue='origin')

# %%
sns.countplot(x = 'cylinders', data=mpg, color='blue', hue='origin')
plt.legend(loc = 'lower right')

# %%
sns.boxplot(y='acceleration', data=mpg)
plt.xlabel('Acceleration')

# %%
sns.boxplot(y='acceleration',x='origin', data=mpg)

# %%
sns.boxplot(y='acceleration',x='cylinders', data=mpg)

# %% [markdown]
# violinplot
# swarmplot
# stripplot

# %% [markdown]
# ## Bivariate distributions

# %% [markdown]
# 1. Scatter plots

# %%
sns.jointplot(x='horsepower',y='acceleration', data=mpg)

# %%
sns.scatterplot(x='horsepower',y='acceleration', data=mpg)

# %%
sns.scatterplot(y='acceleration',x='horsepower', data=mpg, alpha=0.2)

# %%
sns.scatterplot(y='acceleration',x='horsepower', hue='origin', data=mpg)

# %%
plt.subplot(2,2,1)
sns.scatterplot(y='acceleration',x='horsepower', hue='origin', data=mpg)

plt.subplot(2,2,2)
sns.scatterplot(y='acceleration',x='horsepower', data=mpg, alpha=0.2)

plt.subplot(2,2,3)
sns.boxplot(y='acceleration',x='origin', data=mpg)

# %%
plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
sns.scatterplot(y='acceleration',x='horsepower', hue='origin', data=mpg)

plt.subplot(2,2,2)
sns.scatterplot(y='acceleration',x='horsepower', data=mpg, alpha=0.2)

plt.subplot(2,2,3)
sns.boxplot(y='acceleration',x='origin', data=mpg)

# %%
#Save the plot to image
plt.figure(figsize=(10,10))


plt.subplot(2,2,1)
sns.scatterplot(y='acceleration',x='horsepower', hue='origin', data=mpg)

plt.subplot(2,2,2)
sns.scatterplot(y='acceleration',x='horsepower', data=mpg, alpha=0.2)

plt.subplot(2,2,3)
sns.boxplot(y='acceleration',x='origin', data=mpg)

plt.savefig('my_plot.png')

# %%
sns.lmplot(x='horsepower', y='acceleration', data=mpg)

# %%
sns.lmplot(x='horsepower', y='acceleration', hue='origin',data=mpg)

# %%
sns.lmplot(x='horsepower', y='acceleration',col='origin', data=mpg)

# %%
sns.lmplot(x='horsepower', y='acceleration',row='origin', data=mpg)
